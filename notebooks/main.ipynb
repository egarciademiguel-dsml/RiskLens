# %%
import sys

sys.path.append(r"C:\Users\Ordenador\Desktop\Ironhack bootcamp\RiskLens")

# %%
  from src.data.fetch import fetch_asset_data
  from src.data.process import clean_market_data, add_returns
  from src.analytics.risk_metrics import *

  raw = fetch_asset_data("AAPL")
  df = clean_market_data(raw)
  df = add_returns(df)

  print(annualized_volatility(df["returns"]))
  print(max_drawdown(df["close"]))
  print(sharpe_ratio(df["returns"]))
  print(return_statistics(df["returns"]))
  print(rolling_volatility(df["returns"]).tail())
  print(drawdown_series(df["close"]).tail())
# Out:
# 0.27442768692380426
# -0.3336051269846554
# 0.6749432084362669
# {'mean_daily': np.float64(0.0007350123154606976), 'std_daily': np.float64(0.017287319344549478), 'annualized_mean': np.float64(0.18522310349609578), 'annualized_std': np.float64(0.27442768692380426), 'skewness': np.float64(0.4609516083655268), 'kurtosis': np.float64(6.977970470483882), 'min': np.float64(-0.09245616900384979), 'max': np.float64(0.15328857397267126)}
# date
# 2026-03-27    0.186845
# 2026-03-30    0.158399
# 2026-03-31    0.193417
# 2026-04-01    0.195868
# 2026-04-02    0.195686
# Name: returns, dtype: float64
# date
# 2026-03-27   -0.129834
# 2026-03-30   -0.137423
# 2026-03-31   -0.112382
# 2026-04-01   -0.105946
# 2026-04-02   -0.104932
# Name: close, dtype: float64
